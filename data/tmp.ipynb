# %%
from tree_sitter import Language, Parser
from query_pattern import JAVA_QUERY

parser = Parser()
parser.set_language(Language('/home/zixian/PycharmProjects/semantic_graph_code_code_clone/data/my-languages.so', 'java'))
file_path = '/home/zixian/PycharmProjects/semantic_graph_code_code_clone/benchmark/dataset/BCB_tailor/bigclonebench/21386162.java'

with open(file_path, 'rb') as file:
    code = file.read()
    code_ast = parser.parse(code)


# Display the tree structure
root_node = code_ast.root_node

query = JAVA_QUERY()

# _method = query.class_method_query().captures(root_node)[0][0]

# for child in _method.children:
#     print('------------------')
#     root_token = code[child.start_byte:child.end_byte]
#     print(child.type)
#     print(root_token)


# print(_method.type)
# root_token = code[_method.start_byte:_method.end_byte]
# print(root_token)

# %%
from treelib import Tree
from ast_node import ASTNode
import tree_sitter
import uuid

def generate_ast_key(file_name: str, func_name: str, parsed_node: tree_sitter.Node) -> str:
    """ Generate unique key value for each ASTNode

    attributes:
        file_name -- name of the file including current node\\
        parsed_node -- instance of tree_sitter Node is parsed now
    
    returns:
        key_value -- unique key string for parsed_node
    """
    # construct unique string for each tree_sitter Node
    key_str = file_name + '-' + func_name + '-' + parsed_node.type + '-' + str(parsed_node.start_byte) + '-' + str(parsed_node.end_byte)
    key_value = uuid.uuid3(uuid.NAMESPACE_DNS, key_str)
    key_value = str(key_value).replace('-', '')

    return key_value

class Queue():
    """Construct the queue structure using list
    """
    def __init__(self) -> None:
        self.__list = list()
    
    def is_empty(self):
        return self.__list == []
    
    def push(self, data):
        self.__list.append(data)
    
    def pop(self):
        if self.is_empty():
            return False
        
        return self.__list.pop(0)

def build_func_sast(file_name: str, func_name: str, func_tree : tree_sitter.Node, src_code : bytes, exclude_type: list) -> Tree:
    """Build simplified AST (sast) with function as the basic unit

    attributes:
        file_name -- name of the file including current function\\
        func_tree -- function ast generated by tree-sitter\\
        src_code -- serial source code for token querying\\
        exclude_type -- identifier types ignored
    
    returns:
        s_ast -- simplified ast organized by ASTNode
    """
    s_ast = Tree()
    
    # create root node for this function
    root_node = func_tree
    root_key = generate_ast_key(file_name, func_name, root_node)
    has_child = len(root_node.children)
    if not has_child:
        root_token = src_code[root_node.start_byte:root_node.end_byte]
    else:
        root_token = ''
    root_ast = ASTNode(root_key, root_node.type, root_token, root_node.start_byte, root_node.end_byte)
    s_ast.create_node(tag=root_node.type, identifier=root_key, data=root_ast)

    query = JAVA_QUERY()
    ret_node = query.method_ret_query().captures(root_node)[0][0]
    
    # create ret node for each ast
    ret_key = generate_ast_key(file_name, func_name, ret_node)
    ret_token = src_code[ret_node.start_byte:ret_node.end_byte].decode('utf8')
    ret_astnode = ASTNode(ret_key, 'ret_type', ret_token, ret_node.start_byte, ret_node.end_byte)

    queue = Queue()
    queue.push(root_node)
    while not queue.is_empty():
        current_node = queue.pop()

        for child in current_node.children:
            child_type = str(child.type)
            if child_type in exclude_type:
                continue
            child_key = generate_ast_key(file_name, func_name, child)
            child_token = ''
            has_child = len(child.children) > 0
            if not has_child:
                child_token = src_code[child.start_byte:child.end_byte].decode('utf8')
            parent_identifier = generate_ast_key(file_name, func_name, current_node)
            s_ast.create_node(tag=child_type, identifier=child_key, parent=parent_identifier, data=ASTNode(child_key, child_type, child_token, child.start_byte, child.end_byte))

            queue.push(child)
    if s_ast.get_node(ret_key) == None:
        exit(-1)
    
    # remove return parameter node, and place it as return node.
    s_ast.remove_node(ret_key)
    s_ast.create_node(tag=ret_node.type, identifier=ret_key, parent=root_key, data=ret_astnode)

    return s_ast


exclude_type = [",","{",";","}",")","(",'"',"'","`",""," ","[]","[","]",":",".","''","'.'","b", "\\", "'['", "']","''", "comment", "@", "?"]

_method = query.class_method_query().captures(root_node)[0][0]
_m_name_tmp = query.method_declaration_query().captures(_method)
_m_name = code[_m_name_tmp[0][0].start_byte:_m_name_tmp[0][0].end_byte].decode('utf8')

sast = build_func_sast("11.java", _m_name, _method, code, exclude_type)



def print_tree_relationships(tree, node_identifier, level=0):
    node = tree.get_node(node_identifier)
    
    # Print indentation to reflect depth in the tree
    indent = "  " * level
    print(f"{indent}- Node Type: {node.data.node_type}, Identifier: {node.identifier}")
    print(f"{indent}  Node Token: {node.data.node_token}")
    
    # Recursively print all children of the current node
    children = tree.children(node_identifier)
    for child in children:
        print_tree_relationships(tree, child.identifier, level + 1)

# Start the recursive display from the root node of the tree
print("\nTree Relationships (Parent-Child Structure):")
root_identifier = sast.root
print_tree_relationships(sast, root_identifier)
# Out:
# Tree Relationships (Parent-Child Structure):
# - Node Type: method_declaration, Identifier: 27cbd332d2383f14bff63d4aec3f74e9
#   Node Token:
#   - Node Type: modifiers, Identifier: fb778dd000fb3deb868a65ccf34d2f23
#     Node Token:
#     - Node Type: public, Identifier: 436d5091d3ab3c8e9ea40a2c37338d8c
#       Node Token: public
#   - Node Type: identifier, Identifier: 06f00bb006733e2aa47d5fa26bdb8018
#     Node Token: writeToFile
#   - Node Type: formal_parameters, Identifier: 99e805baf24539cf9ec708e03a9fa005
#     Node Token:
#     - Node Type: formal_parameter, Identifier: a33198318d4635f6a1fe23bc91496dba
#       Node Token:
#       - Node Type: type_identifier, Identifier: d8c5f94a6b8a3227b7c7a917074f36ba
#         Node Token: File
#       - Node Type: identifier, Identifier: 840040bff93337ab99a3ea550a3368a5
#         Node Token: file
#     - Node Type: formal_parameter, Identifier: 6c86c018685e381f9f098bea9c292e09
#       Node Token:
#       - Node Type: type_identifier, Identifier: 6d068e87e22f3edfbd247b14df2235c4
#         Node Token: File
#       - Node Type: identifier, Identifier: 0d7d358729a5378ebd0b846fe3f8664b
#         Node Token: source
#   - Node Type: throws, Identifier: d2ee7675d934318c8d03447025f3c2a8
#     Node Token:
#     - Node Type: throws, Identifier: 9cac56e01d8a3179a846ec688bdecf90
#       Node Token: throws
#     - Node Type: type_identifier, Identifier: 6ff62044dedb39e59661ffb033392448
#       Node Token: IOException
#   - Node Type: block, Identifier: 023e019776e03a8b95340db6b44362b2
#     Node Token:
#     - Node Type: local_variable_declaration, Identifier: 7fab395ccaf53547b6b7c5d8e8edfd8e
#       Node Token:
#       - Node Type: type_identifier, Identifier: 0978f1d3edd33d2c8b686d4aabc8584a
#         Node Token: BufferedOutputStream
#       - Node Type: variable_declarator, Identifier: 44ac89da02ad3a1fa21d961c30c4a2a7
#         Node Token:
#         - Node Type: identifier, Identifier: c17cb67ff2ce304cb9946623beda6106
#           Node Token: bout
#         - Node Type: =, Identifier: 5592d970c5ee38c691e4d4724cc745f6
#           Node Token: =
#         - Node Type: object_creation_expression, Identifier: 16a341f875103336928e0deb38bedb9e
#           Node Token:
#           - Node Type: new, Identifier: c7ab4be01d8b3b7b978ed1384d1405e2
#             Node Token: new
#           - Node Type: type_identifier, Identifier: 6d73c39b93ed35b5897535cef6599c48
#             Node Token: BufferedOutputStream
#           - Node Type: argument_list, Identifier: d12eb1ea9deb3546a42302731fb33a98
#             Node Token:
#             - Node Type: object_creation_expression, Identifier: ad04e9e450cf3597a4a7e9bed9b1386e
#               Node Token:
#               - Node Type: new, Identifier: ad056b66743b3aefb1180c1752cbe2e8
#                 Node Token: new
#               - Node Type: type_identifier, Identifier: 30cf8061790834f687c61d6ac986e3dc
#                 Node Token: FileOutputStream
#               - Node Type: argument_list, Identifier: 61d49714c18a3908b527ad8a8e147682
#                 Node Token:
#                 - Node Type: identifier, Identifier: 4a0748bf4e2538ccb2756713e155aa36
#                   Node Token: file
#     - Node Type: local_variable_declaration, Identifier: 942f98d294f736b19c7207d4f35b3707
#       Node Token:
#       - Node Type: type_identifier, Identifier: a418a383ee753fb39d9f2138c41c1f49
#         Node Token: BufferedInputStream
#       - Node Type: variable_declarator, Identifier: 4378419385303850bd24367b1dcb7bf0
#         Node Token:
#         - Node Type: identifier, Identifier: a6a473b7fe313b5e994e9f2cc64b0829
#           Node Token: bin
#         - Node Type: =, Identifier: 218775e266c63e2f96c334186c2943fb
#           Node Token: =
#         - Node Type: object_creation_expression, Identifier: a6a75bdac9643455a9081d533b498741
#           Node Token:
#           - Node Type: new, Identifier: 21cf9d3f0b3639038dec6a592920526e
#             Node Token: new
#           - Node Type: type_identifier, Identifier: 951740ac23033fff913c860ae57da758
#             Node Token: BufferedInputStream
#           - Node Type: argument_list, Identifier: 004db4d70a3b3e22a152b55c348df219
#             Node Token:
#             - Node Type: object_creation_expression, Identifier: f965973d87a13878bcbaea55056ad457
#               Node Token:
#               - Node Type: new, Identifier: c39296bd5e1d3d59a58618498e293133
#                 Node Token: new
#               - Node Type: type_identifier, Identifier: d15c6840950c3daea1f18870c7a2a482
#                 Node Token: FileInputStream
#               - Node Type: argument_list, Identifier: b164605f75fe39bdb99b9dd9ebb5dd6e
#                 Node Token:
#                 - Node Type: identifier, Identifier: 47f74e37d9d43960bb84bf843d7d740d
#                   Node Token: source
#     - Node Type: expression_statement, Identifier: 8e4c12482c923f45a6e27a36d6d87f83
#       Node Token:
#       - Node Type: method_invocation, Identifier: 3412f93e5b3536efa7df60266b351c3c
#         Node Token:
#         - Node Type: identifier, Identifier: bee0c9340fed3b459a5a12917b3962a1
#           Node Token: bin
#         - Node Type: identifier, Identifier: 40095dbd58c030b295fa8543f3906f30
#           Node Token: skip
#         - Node Type: argument_list, Identifier: bc5330176b1a3841905aaccd99fb1214
#           Node Token:
#           - Node Type: method_invocation, Identifier: 27b2c63dce9939de829eb9a8170660f3
#             Node Token:
#             - Node Type: identifier, Identifier: 9b8de10803b934e9a5b4d7f4c6b413c0
#               Node Token: header
#             - Node Type: identifier, Identifier: c434d817f2cb31afbb55d069fdeb3767
#               Node Token: getHeaderEndingOffset
#             - Node Type: argument_list, Identifier: 3172c98ba4d43a95b1f67b6978001b21
#               Node Token:
#     - Node Type: for_statement, Identifier: e082de02d73036859ae3e84d3ca631f0
#       Node Token:
#       - Node Type: for, Identifier: e068c788242b3719a4ffd4981b415117
#         Node Token: for
#       - Node Type: local_variable_declaration, Identifier: b4de606a7a0a3e8d9ed7e92847581c04
#         Node Token:
#         - Node Type: integral_type, Identifier: 2ae8b648e7ab30cd99467a4d02cfefa8
#           Node Token:
#           - Node Type: long, Identifier: 1cb5e656604733aa8d6c665588a2a024
#             Node Token: long
#         - Node Type: variable_declarator, Identifier: b335b08c519c3350baaf4e57ae269382
#           Node Token:
#           - Node Type: identifier, Identifier: 19a0316f9bbb3c72a684db509da179c0
#             Node Token: i
#           - Node Type: =, Identifier: 7491c4a97f3d3403ba226104922ede14
#             Node Token: =
#           - Node Type: decimal_integer_literal, Identifier: 99067310a2a139db87086f60aec24fc6
#             Node Token: 0
#       - Node Type: binary_expression, Identifier: 0fecd4f393733f9f91b763ff6cb27f4f
#         Node Token:
#         - Node Type: identifier, Identifier: 99cdf353da9a3dc5a9e5e7434b7ad53a
#           Node Token: i
#         - Node Type: <, Identifier: fd28fa5b403f305c89cc14b6e76a9c89
#           Node Token: <
#         - Node Type: field_access, Identifier: 4c2a41b355783412b293f1485f24bb5f
#           Node Token:
#           - Node Type: this, Identifier: 32013aa6b2673b4aac73a1e0290205be
#             Node Token: this
#           - Node Type: identifier, Identifier: 658dccfd2a583a698d76b932875a2580
#             Node Token: streamLength
#       - Node Type: update_expression, Identifier: 376e908744cf3f378fb86d14cc54f8e2
#         Node Token:
#         - Node Type: identifier, Identifier: 92dff3f1ccaa3218b0f5658563b4a9ef
#           Node Token: i
#         - Node Type: ++, Identifier: 1b6aa1ecd2fa30ed81780df1451dcc12
#           Node Token: ++
#       - Node Type: block, Identifier: b1baa767b2103d3e9a67ade39961be82
#         Node Token:
#         - Node Type: expression_statement, Identifier: efb737ab35ad340dbf66e6ed6ad31db4
#           Node Token:
#           - Node Type: method_invocation, Identifier: ba24185227f73eba89017ecef1f7e0f1
#             Node Token:
#             - Node Type: identifier, Identifier: 5f7b1a4741713a8bb7d5b618d2c70acb
#               Node Token: bout
#             - Node Type: identifier, Identifier: d75d55018d503dfcbc6d18a33fec0ec4
#               Node Token: write
#             - Node Type: argument_list, Identifier: 5aca5693f6a933b885d237a9ec71fb88
#               Node Token:
#               - Node Type: method_invocation, Identifier: 1497cbc0eae7397f8b4e12d523a25ebe
#                 Node Token:
#                 - Node Type: identifier, Identifier: c6cf0d1e4fdc31dbbf0f48258cfe0fc9
#                   Node Token: bin
#                 - Node Type: identifier, Identifier: c9db9fd2970e36d0864a24e8add7ba8e
#                   Node Token: read
#                 - Node Type: argument_list, Identifier: 5fb1430d0f5731eb98baa1f09211a373
#                   Node Token:
#     - Node Type: expression_statement, Identifier: 4c794db710743e60af21dbde9fd74db1
#       Node Token:
#       - Node Type: method_invocation, Identifier: 5b94cdac6bed3f969bcf3a7f8aac4475
#         Node Token:
#         - Node Type: identifier, Identifier: decacc40fe8633f7b22964cf25fd8d0a
#           Node Token: bin
#         - Node Type: identifier, Identifier: df3aa1f39a0331ef9ad2de9dfda7415e
#           Node Token: close
#         - Node Type: argument_list, Identifier: 7319868b9db337ba830f407793121627
#           Node Token:
#     - Node Type: expression_statement, Identifier: 82f912341be539a5a04793177e47fd1a
#       Node Token:
#       - Node Type: method_invocation, Identifier: 17e2a77296ad38c69055640853e9da07
#         Node Token:
#         - Node Type: identifier, Identifier: 44bebeaf21313beba5bba780e5378fe5
#           Node Token: bout
#         - Node Type: identifier, Identifier: d1f5391a415b37698d4dafd646130a81
#           Node Token: close
#         - Node Type: argument_list, Identifier: 91f78de7f2d835bcad070c46fe2279f8
#           Node Token:
#   - Node Type: ret_type, Identifier: b2433cacd00738debdca00ae55acb813
#     Node Token: void
